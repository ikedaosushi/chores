// %%
'use strict';
// Out:
// 'use strict'

// %%
var Twitter = require('twitter')
  , _       = require('lodash')
  , chatwork_tmplt = _.template('[info][title]<%= title %>[/title]<%= wrap %>\r\n<%= url %>[/info]')
  , client = new Twitter({
      consumer_key: 'ir2DksYpe9hmzPJnLqKBGxQCe',
      consumer_secret: 'm39ne6P8JgLGQRMy74jIvMTtdh3L6yftrkDd5LzTOSkAZT8Cxp',
      access_token_key: '136669186-vj2ii7uIqcFdy5FTm7KMIibQWdMlcwNBZgGBXTCF',
      access_token_secret: 'E5O4U0xe5UhNpQhcs3ah2teCJ31AfJjyJGf29vjkfNuFh'
    })
  ;
// Out:
// undefined

// %%
var now = new Date()
  , oneHourAgo = new Date(now.getFullYear(), now.getMonth(), now.getDate(), now.getHours() - 1, now.getMinutes())
  ;
// Out:
// undefined

// %%
function extractLatestTweets(tweets){
  return _.filter(tweets, function(e, i){
    return oneHourAgo > new Date(e['created_at'])
  }).map(function(e, i){
    return chatwork_tmplt({
        title: 'hillbig',
        wrap : e['text'],
        url  : 'https://twitter.com/hillbig/status/' + e['id_str']
    });
  });
};
// Out:
// undefined

// %%
  _.filter(tweetsTmp, function(e, i){
    return oneHourAgo > new Date(e['created_at']);
  }).map(function(e, i){
    return e;
  });
// Out:
// [ { created_at: 'Tue Apr 18 00:55:28 +0000 2017',
//     id: 854136263456075800,
//     id_str: '854136263456075776',
//     text: '予測分布が最も大きく変わる敵対的な入力のノイズを見つけ、そのノイズを加えた後でも予測分布が変わらないようにする正則化であるVATのジャーナル版。SVHN, CIFAR-10の半教師あり学習でSoTA。PFNの宮戸/前田の仕事 https://t.co/IV36b7NZGW',
//     truncated: false,
//     entities: { hashtags: [], symbols: [], user_mentions: [], urls: [Object] },
//     source: '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
//     in_reply_to_status_id: null,
//     in_reply_to_status_id_str: null,
//     in_reply_to_user_id: null,
//     in_reply_to_user_id_str: null,
//     in_reply_to_screen_name: null,
//     user:
//      { id: 12483052,
//        id_str: '12483052',
//        name: '岡野原 大輔',
//        screen_name: 'hillbig',
//        location: '東京都江東区',
//        description: 'PFI, PFNで取締役副社長をしてます。深層学習/人工知能/データ構造/アルゴリズム/大規模分散並列/NLPが好きです。Go,C++',
//        url: 'https://t.co/8KiVAyYQLZ',
//        entities: [Object],
// ...

// %%
_.filter(tweetsTmp, function(element, index){
  return element['created_at'] < oneHourAgo
});
// Out:
// []

// %%
tweetsTmp
// Out:
// [ { created_at: 'Tue Apr 18 00:55:28 +0000 2017',
//     id: 854136263456075800,
//     id_str: '854136263456075776',
//     text: '予測分布が最も大きく変わる敵対的な入力のノイズを見つけ、そのノイズを加えた後でも予測分布が変わらないようにする正則化であるVATのジャーナル版。SVHN, CIFAR-10の半教師あり学習でSoTA。PFNの宮戸/前田の仕事 https://t.co/IV36b7NZGW',
//     truncated: false,
//     entities: { hashtags: [], symbols: [], user_mentions: [], urls: [Object] },
//     source: '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
//     in_reply_to_status_id: null,
//     in_reply_to_status_id_str: null,
//     in_reply_to_user_id: null,
//     in_reply_to_user_id_str: null,
//     in_reply_to_screen_name: null,
//     user:
//      { id: 12483052,
//        id_str: '12483052',
//        name: '岡野原 大輔',
//        screen_name: 'hillbig',
//        location: '東京都江東区',
//        description: 'PFI, PFNで取締役副社長をしてます。深層学習/人工知能/データ構造/アルゴリズム/大規模分散並列/NLPが好きです。Go,C++',
//        url: 'https://t.co/8KiVAyYQLZ',
//        entities: [Object],
// ...

// %%
var params = {screen_name: 'hillbig'};
client.get('statuses/user_timeline', params)
  .then(function(tweets) {
    console.log(tweets);
    tweetsTmp = tweets;
});
// Out:
// Promise { <pending> }
// [ { created_at: 'Tue Apr 18 00:55:28 +0000 2017',
//     id: 854136263456075800,
//     id_str: '854136263456075776',
//     text: '予測分布が最も大きく変わる敵対的な入力のノイズを見つけ、そのノイズを加えた後でも予測分布が変わらないようにする正則化であるVATのジャーナル版。SVHN, CIFAR-10の半教師あり学習でSoTA。PFNの宮戸/前田の仕事 https://t.co/IV36b7NZGW',
//     truncated: false,
//     entities: { hashtags: [], symbols: [], user_mentions: [], urls: [Object] },
//     source: '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
//     in_reply_to_status_id: null,
//     in_reply_to_status_id_str: null,
//     in_reply_to_user_id: null,
//     in_reply_to_user_id_str: null,
//     in_reply_to_screen_name: null,
//     user:
//      { id: 12483052,
//        id_str: '12483052',
//        name: '岡野原 大輔',
//        screen_name: 'hillbig',
//        location: '東京都江東区',
//        description: 'PFI, PFNで取締役副社長をしてます。深層学習/人工知能/データ構造/アルゴリズム/大規模分散並列/NLPが好きです。Go,C++',
//        url: 'https://t.co/8KiVAyYQLZ',
// ...

// %%
var request = require('superagent');
// Out:
// undefined

// %%
request
    .get('https://api.github.com/repos/arXivTimes/arXivTimes/issues')
    .end(function(err, res){
        response = res;
    });
// Out:
// Request {
//   domain: null,
//   _events: { end: { [Function: g] listener: [Function: bound _clearTimeout] } },
//   _eventsCount: 1,
//   _maxListeners: undefined,
//   _agent: false,
//   _formData: null,
//   method: 'GET',
//   url: 'https://api.github.com/repos/arXivTimes/arXivTimes/issues',
//   _header: { 'user-agent': 'node-superagent/3.4.4' },
//   header: { 'User-Agent': 'node-superagent/3.4.4' },
//   writable: true,
//   _redirects: 0,
//   _maxRedirects: 5,
//   cookies: '',
//   qs: {},
//   qsRaw: [],
//   _redirectList: [],
//   _streamRequest: false,
//   req:
//    ClientRequest {
//      domain: null,
//      _events:
//       { socket: [Object],
//         drain: [Object],
//         error: [Object],
//         response: [Object] },
//      _eventsCount: 4,
//      _maxListeners: undefined,
// ...

// %%
// response_json = JSON.parse(response.text)
// Out:
// undefined

// %%
var now = new Date();
var yesterday = new Date(now.getFullYear(), now.getMonth(), now.getDate() - 1);
// Out:
// undefined

// %%
chatwork_tmplt = _.template('[info][title]<%= title %>[/title]<%= wrap %>\r\n<%= url %>[/info]');
// Out:
// { [Function]
//   source: 'function(obj) {\nobj || (obj = {});\nvar __t, __p = \'\';\nwith (obj) {\n__p += \'[info][title]\' +\n((__t = ( title )) == null ? \'\' : __t) +\n\'[/title]\' +\n((__t = ( wrap )) == null ? \'\' : __t) +\n\'\\r\\n\' +\n((__t = ( url )) == null ? \'\' : __t) +\n\'[/info]\';\n\n}\nreturn __p\n}' }

// %%
message = _.filter(response_json, function(ele, idx){
    var ele_date = Date.parse(ele['updated_at']);
    return yesterday < ele_date
}).map(function(ele, idx){
    var title = ele['title']
    var url = ele['html_url']
    var wrap = ele['body'].match(/## 一言[\s\S]*### 論文/)[0]
        .replace('## 一言でいうと\r\n', '')
        .replace('\r\n\r\n### 論文', '');
    return chatwork_tmplt({
        'title': title,
        'wrap': wrap,
        'url': url
    });
}).join("\r\n");
// Out:
// '[info][title]Image Restoration Using Very Deep Convolutional Encoder-Decoder Networks with Symmetric Skip Connections[/title]一枚の画像からその解像度を上げる単画像超解像の論文。\r\nILSVRC 2015のWinnerであるResNetの手法を取り入れて30層という当時最もディープなモデルを提案し最高性能を獲得し。シンプルでdeepなモデルが良いというトレンドを実証した。\r\n\r\n通称はRED-Net\r\nhttps://github.com/arXivTimes/arXivTimes/issues/221[/info]\r\n[info][title]Accurate Image Super-Resolution Using Very Deep Convolutional Networks[/title]一枚の画像からその解像度を上げる単画像超解像の論文。\r\nILSVRC 2015のWinnerであるResNetの手法を取り入れて残差項の推定に特化し、学習係数を従来の1万倍に設定し非常に早い時点での収束を実現した。それでいて性能もほぼ最高性能であった。\r\n\r\n[ CVPR2016 オーラル発表論文　通称はVDSR ]\r\nhttps://github.com/arXivTimes/arXivTimes/issues/220[/info]\r\n[info][title]Deeply-Recursive Convolutional Network for Image Super-Resolution[/title]一枚の画像からその解像度を上げる単画像超解像の論文。\r\n16枚の同じCNNを繰り返し適用して少しづつ高解像画像の推定を行なっている。プーリングを利用せずに合計で20枚ものCNNを適用しているが、同じCNNパラメータを利用することで学習の発散を抑えているのが特徴。\r\n\r\n[ CVPR2016採択論文 通称はDRCN ]\r\n\r\nhttps://github.com/arXivTimes/arXivTimes/issues/219[/info]\r\n[info][title]Image
// ...

// %%
var $ = require('jquery');
// Out:
// undefined

// %%
var request = require('super');
// Out:
// Error: Cannot find module 'requests'
//     at Function.Module._resolveFilename (module.js:326:15)
//     at Function.Module._load (module.js:277:25)
//     at Module.require (module.js:354:17)
//     at require (internal/module.js:12:17)
//     at evalmachine.<anonymous>:1:15
//     at Object.exports.runInThisContext (vm.js:54:17)
//     at run ([eval]:613:19)
//     at onRunRequest ([eval]:384:22)
//     at onMessage ([eval]:352:17)
//     at emitTwo (events.js:87:13)

// %%
now.ge
// Out:
// Mon Feb 20 2017 12:11:08 GMT+0900 (JST)

// %%
month = now.getMonth() + 1
// Out:
// 2

// %%
now.getFullYear() + '-' + month + '-' + now.getDate()
// Out:
// '2017-2-20'

// %%
request
    .post(url)
    .field('body', message)
    .set('X-ChatWorkToken', '03de1d3a24aeb0392fcba36381804d0b')
    .end(function(err, res){
        console.log(res);
    });
// Out:
// Request {
//   domain: null,
//   _events: { end: { [Function: g] listener: [Function: bound _clearTimeout] } },
//   _eventsCount: 1,
//   _maxListeners: undefined,
//   _agent: false,
//   _formData:
//    FormData {
//      _overheadLength: 103,
//      _valueLength: 2016,
//      _valuesToMeasure: [],
//      writable: false,
//      readable: true,
//      dataSize: 0,
//      maxDataSize: 2097152,
//      pauseStreams: true,
//      _released: false,
//      _streams:
//       [ '----------------------------172806690679396721591538\r\nContent-Disposition: form-data; name="body"\r\n\r\n',
// ...

// %%
var room_id = '32236319';
var url = 'https://api.chatwork.com/v2/rooms/'+room_id+'/messages';
var body = { body: 'hello'};
// Out:
// undefined

// %%
var room_id = '32236319';
var options = {
    url: 'https://api.chatwork.com/v2/rooms/'+room_id+'/messages',
    headers: {
        'X-ChatWorkToken': '03de1d3a24aeb0392fcba36381804d0b'
    },
    form: { body: 'hello' },
    json: true
};

request.post(options, function (error, response, body) {
    if (!error && response.statusCode == 200) {
        console.log(response);
    }else{
        test = response
        console.log('error: '+ response.statusCode);
    }
});
// Out:
// Request {
//   domain: null,
//   _events: { end: { [Function: g] listener: [Function: bound _clearTimeout] } },
//   _eventsCount: 1,
//   _maxListeners: undefined,
//   _agent: false,
//   _formData: null,
//   method: 'POST',
//   url: '',
//   _header: { 'user-agent': 'node-superagent/3.4.4' },
//   header: { 'User-Agent': 'node-superagent/3.4.4' },
//   writable: true,
//   _redirects: 0,
//   _maxRedirects: 5,
//   cookies: '',
//   qs: {},
//   qsRaw: [],
//   _redirectList: [],
//   _streamRequest: false,
//   req:
//    ClientRequest {
//      domain: null,
//      _events:
//       { socket: [Object],
//         drain: [Object],
//         error: [Object],
//         response: [Object] },
//      _eventsCount: 4,
//      _maxListeners: undefined,
//      output: [ 'POST / HTTP/1.1\r\nHost: localhost\r\nAccept-Encoding: gzip, deflate\r\nUser-Agent: node-superagent/3.4.4\r\nConnection: close\r\nContent-Length: 0\r\n\r\n' ],
//      outputEncodings: [ 'binary' ],
// ...

// %%
_ = require('lodash');
// Out:
// { [Function: lodash]
//   templateSettings:
//    { escape: /<%-([\s\S]+?)%>/g,
//      evaluate: /<%([\s\S]+?)%>/g,
//      interpolate: /<%=([\s\S]+?)%>/g,
//      variable: '',
//      imports: { _: [Circular] } },
//   after: [Function: after],
//   ary: [Function: ary],
//   assign: [Function],
//   assignIn: [Function],
//   assignInWith: [Function],
//   assignWith: [Function],
//   at: [Function],
//   before: [Function: before],
//   bind: { [Function] placeholder: [Circular] },
//   bindAll: [Function],
//   bindKey: { [Function] placeholder: [Circular] },
//   castArray: [Function: castArray],
//   chain: [Function: chain],
//   chunk: [Function: chunk],
//   compact: [Function: compact],
//   concat: [Function: concat],
//   cond: [Function: cond],
//   conforms: [Function: conforms],
//   constant: [Function: constant],
//   countBy: [Function],
//   create: [Function: create],
//   curry: { [Function: curry] placeholder: [Circular] },
// ...
